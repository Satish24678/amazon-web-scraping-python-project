# %%
from bs4 import BeautifulSoup
import requests
import numpy as np
import pandas as pd

# %%
# Function to extract Product Title
def get_title(soup):
    
    try:
        # Outer Tag Object
        title = soup.find("span", attrs={"id": 'productTitle'})
        
        # Innner NavigatableString Object
        title_value = title.text
        
        # Title as a string value
        title_string = title_value.strip()
        
    except AttributeError:
        title_string = " "
        
    return title_string

# Function to extract Product Price
def get_price(soup):
    
    try:
        price = soup.find("span", attrs={"id": 'priceblock_ourprice'}).string.strip()

    except AttributeError:
        try:
            # If there is some deal price
            price = soup.find("span", attrs={"id": 'priceblock_dealprice'}).string.strip()
  
        except:
            price = ""
            
    return price

# Function to extract Product Rating
def get_rating(soup):
    
    try:
        rating = soup.find("i", attrs={'class':'a-icon a-icon-star a-star-4-5'}).string.strip()
    
    except AttributeError:
        try:
            rating = soup.find("span", attrs={'class':'a-icon-alt'}).string.strip()
        except:
            rating = ""	

    return rating

# Function to extract Number of User Reviews
def get_review_count(soup):
    try:
        review_count = soup.find("span", attrs= {'id':'acrCustomerReviewText'}).string.strip()
        
    except AttributeError:
        review_count = ""
        
    return review_count

# Function to extract Availability Status
def get_availability(soup):
    try:
        available = soup.find("div", attrs= {'id': 'availability'})
        available = available.find("span").string.strip()
        
    except AttributeError:
        available = "Not Available"	

    return available

# %%
if __name__ == '__main__':
    
    # Add your user agent
    HEADERS = ({'User-Agent': '', 'Accept-Language': 'en-US, en;q=0.5'})
    
    # The webpage URL 
    URL = "https://www.amazon.com/s?k=playstation+4&ref=nb_sb_noss_2"
    
    # HTTP Request
    webpage = requests.get(URL, headers = HEADERS)
    
    # Soup Object containing all data
    soup = BeautifulSoup(webpage.content, "html.parser")
    
    # Fetch links as List of Tag Objects
    links = soup.find_all("a", attrs = {'class':'a-link-normal s-no-outline'})

    # Store the links
    links_list = []
    
    # Look for extracting links from Tag Objects
    for link in links:
        links_list.append(link.get('href'))
        
    d = {"title": [], "price":[], "rating":[], "reviews":[],"availability":[]}
    
    # Loop for extracting product details from each link
    for link in links_list:
        new_webpage = requests.get("https://www.amazon.com" + link, headers=HEADERS)

        new_soup = BeautifulSoup(new_webpage.content, "html.parser")

        # Function calls to display all necessary product information
        d['title'].append(get_title(new_soup))
        d['price'].append(get_price(new_soup))
        d['rating'].append(get_rating(new_soup))
        d['reviews'].append(get_review_count(new_soup))
        d['availability'].append(get_availability(new_soup))

    
    amazon_df = pd.DataFrame.from_dict(d)
    amazon_df['title'].replace('', np.nan, inplace=True)
    amazon_df = amazon_df.dropna(subset=['title'])
    amazon_df.to_csv("amazon_data.csv", header=True, index=False)

# %%
amazon_df
# Out:
#                                                 title price  \
# 0              Sony Playstation PS4 1TB Black Console
# 1                      PlayStation 4 Slim 1TB Console
# 2              Sony PlayStation 4 Pro 1TB White (PS4)
# 3   DualShock 4 Wireless Controller for PlayStatio...
# 4   Logitech G29 Driving Force Racing Wheel and Fl...
# 5                     Sonic Frontiers - PlayStation 4
# 6   BlueFire Professional 3.5mm PS4 Gaming Headset...
# 7   PS4 Fan Cooling Fan with Controller Charger Co...
# 8   RPlay Play-Station 4 PS4 1TB Slim Edition Jet ...
# 9   PlayStation 4 500GB Console [Old Model][Discon...
# 10  Sony PlayStation 4 Pro 1TB Console - Black (PS...
# 11  Flagship Newest Play Station 4 1TB HDD Only on...
# 12  Playstation Sony 4, 500GB Slim System [CUH-221...
# 13  DualShock 4 Wireless Controller for PlayStatio...
# 14  PlayStation PS5 Console – God of War Ragnarök ...
# 15  eeidc 2 Pack Wireless Controller for PS4, Remo...
# 16  Skylanders SWAP Force Starter Pack - PlayStati...
# 17  DualShock 4 Wireless Controller for PlayStatio...
# 18  DualShock 4 Wireless Controller for PlayStatio...
# 19         Sony Playstation 4 Dual Shock 4 Controller
# 20  Wiv77 Ymir Wireless Controller Compatible with...
# 21                    Sonic Frontiers - PlayStation 4
# 22                      LEGO 2K Drive - PlayStation 4
# 23  Skylanders SuperChargers Dark Edition Starter ...
# 24  Tatybo 7.1 Surround Sound Gaming Headset for P...
# 25  Aoidaruy Wireless Controller for PS4, Compatib...
#
#                                          rating          reviews  \
# 0                            4.7 out of 5 stars    1,024 ratings
# 1                            4.7 out of 5 stars   15,388 ratings
# 2                            4.4 out of 5 stars      938 ratings
# 3                            4.7 out of 5 stars  145,389 ratings
# 4                            4.7 out of 5 stars   16,201 ratings
# 5                            4.8 out of 5 stars      448 ratings
# 6                            4.4 out of 5 stars    8,427 ratings
# 7                            4.3 out of 5 stars    1,315 ratings
# 8                            4.8 out of 5 stars        8 ratings
# 9                            4.6 out of 5 stars   13,656 ratings
# 10                           4.5 out of 5 stars    4,202 ratings
# 11                           4.6 out of 5 stars      179 ratings
# 12                           4.5 out of 5 stars      307 ratings
# 13                           4.7 out of 5 stars  145,389 ratings
# 14                           4.8 out of 5 stars    6,481 ratings
# 15                           5.0 out of 5 stars         1 rating
# 16                           4.5 out of 5 stars      337 ratings
# 17                           4.7 out of 5 stars  145,389 ratings
# 18                           4.7 out of 5 stars  145,389 ratings
# 19                           4.6 out of 5 stars    2,246 ratings
# 20                           5.0 out of 5 stars         1 rating
# 21                           4.8 out of 5 stars      448 ratings
# 22  Previous page of related Sponsored Products
# 23                           4.6 out of 5 stars      361 ratings
# 24                           4.3 out of 5 stars      235 ratings
# 25                           5.0 out of 5 stars        2 ratings
#
#                                    availability
# 0                                 Not Available
# 1
# 2             Only 2 left in stock - order soon
# 3                                 Not Available
# 4
# 5                                      In Stock
# 6                                 Not Available
# 7                                 Not Available
# 8                                 Not Available
# 9             Only 2 left in stock - order soon
# 10            Only 3 left in stock - order soon
# 11                                Not Available
# 12                                Not Available
# 13                                Not Available
# 14                                     In Stock
# 15                                Not Available
# 16                                Not Available
# 17                                Not Available
# 18                                Not Available
# 19                                Not Available
# 20                                Not Available
# 21                                     In Stock
# 22  This item will be released on May 19, 2023.
# 23                                Not Available
# 24                                Not Available
# 25                                Not Available
